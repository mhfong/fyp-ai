# %%
import requests
import re

keys = ['QQQ']
url = "https://www.investopedia.com/ask/answers/061715/what-qqq-etf.asp"
holdings = []

with requests.Session() as req:
    req.headers.update(headers)
    for key in keys:
        r = req.get(url.format(key))
        print(f"Extracting: {r.url}")
        print(r.text)
        #holdings = re.findall(r'etf\\\/(.*?)\\', r.text)



#holdings
# Out:
# Extracting: https://www.investopedia.com/ask/answers/061715/what-qqq-etf.asp
# <!DOCTYPE html>
# <html id="scTemplate_2-0" class="comp no-js new-layout-breakpoints-vertical scTemplate html mntl-html" data-ab="78,75,54,99,67,99,66,99" data-resource-version="1.215.0" lang="en" data-mantle-resource-version="3.12.852" data-finance-resource-version="1.215.0" data-tracking-container="true">
# <!--
# <globe-environment environment="k8s-prod" application="finance" dataCenter="us-west-1"/>
# -->
# <head class="loc head">
# <script type="text/javascript">var Mntl = window.Mntl || {};</script>
# <link rel="preconnect" href="//c.amazon-adsystem.com">
# <link rel="preconnect" href="//securepubads.g.doubleclick.net">
# <meta charset="utf-8">
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
# <meta name="robots" content="max-image-preview:large, NOODP, NOYDIR" />
# <meta name="viewport" content="width=device-width, initial-scale=1.0">
# ...

# %%
import yfinance as yf


hist = yf.Ticker("AAPL").history(period="max")["High"]
hist.head()
# Out:
# Date
# 1980-12-12    0.100759
# 1980-12-15    0.095525
# 1980-12-16    0.088546
# 1980-12-17    0.090727
# 1980-12-18    0.093345
# Name: High, dtype: float64
